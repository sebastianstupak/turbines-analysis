# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/us.csv')

plt.figure(figsize=(10, 6))
df.boxplot(column=['t_hh', 't_rd', 't_ttlh'])

plt.title('Wind Turbine Dimensions')
plt.ylabel('Meters')

plt.show()
